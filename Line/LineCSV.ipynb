# %%
from pyecharts.charts import Line
from pyecharts import options as opts

from pyecharts.globals import ThemeType, RenderType
from pyecharts.faker import Faker

# %%
line = (
    Line()
    .add_xaxis(['2015', '2016', '2017', '2018', '2019'])
    .add_yaxis('比例%', [30.23, 15.06, 17.6, 16.56, 18.51])
    .add_yaxis('比%', [33, 75.06, 27.6, 56.56, 88.51])
    
    .set_global_opts(title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"))
)

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bbe6e4175c2449e5a24d0a181a8611cb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bbe6e4175c2449e5a24d0a181a8611cb = echarts.init(
#                     document.getElementById('bbe6e4175c2449e5a24d0a181a8611cb'), 'white', {renderer: 'canvas'});
#                 var option_bbe6e4175c2449e5a24d0a181a8611cb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6bd4\u4f8b%",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2015",
#                     30.23
#                 ],
#                 [
#                     "2016",
#                     15.06
#                 ],
#                 [
#                     "2017",
#                     17.6
#                 ],
#                 [
#                     "2018",
#                     16.56
#                 ],
#                 [
#                     "2019",
#                     18.51
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u6bd4%",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2015",
#                     33
#                 ],
#                 [
#                     "2016",
#                     75.06
#                 ],
#                 [
#                     "2017",
#                     27.6
#                 ],
#                 [
#                     "2018",
#                     56.56
#                 ],
#                 [
#                     "2019",
#                     88.51
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6bd4\u4f8b%",
#                 "\u6bd4%"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2015",
#                 "2016",
#                 "2017",
#                 "2018",
#                 "2019"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e3b\u6807\u9898",
#             "target": "blank",
#             "subtext": "\u526f\u6807\u9898",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_bbe6e4175c2449e5a24d0a181a8611cb.setOption(option_bbe6e4175c2449e5a24d0a181a8611cb);
#         });
#     </script>

# %%
line1 = Line(
    init_opts=opts.InitOpts(
        renderer=RenderType.CANVAS, # 渲染模式，可选'render_type=RenderType.CANVAS'或'render_type=RenderType.SVG'
        page_title="Bar-RenderType.html", # 网页标题
        theme=ThemeType.LIGHT, # 主题
        bg_color="transparent", # 背景颜色
        
        
    )
)
x = Faker.choose()
line1.add_xaxis(x)
line1.add_yaxis("A", Faker.values())
line1.add_yaxis("B", Faker.values())


# 全局配置项，可选项
line1.set_global_opts(
    title_opts=opts.TitleOpts(
        title="主标题", 
        title_link="https://www.baidu.com", # 主标题超链接
        subtitle="副标题",
        subtitle_link="https://www.baidu.com", # 副标题超链接
        
        # 标题位置
        pos_left="5px", # 标题水平位置，可选'left', 'center', 'right'
        ),
    # 缩放配置项
    datazoom_opts=opts.DataZoomOpts(
        is_show=True, # 是否显示
        type_="slider", # 缩放类型，可选'slider', 'inside'
        is_realtime=True, # 是否实时显示
    ),
    # 图例配置项
    legend_opts=opts.LegendOpts(
        is_show=True, # 是否显示
        type_="scroll", # 图例类型，可选'plain', 'scroll'
        pos_right="5px", # 图例水平位置，可选'left', 'center', 'right'
        orient="horizontal", # 图例垂直位置，可选'horizontal', 'vertical'
        legend_icon="circle", # 图例形状，可选'circle', 'rect', 'roundRect', 'triangle', 'diamond', 'pin', 'arrow', 'none'
    ),
    # VisualMap配置项
    # visualmap_opts=opts.VisualMapOpts(
        # is_show=True, # 是否显示
        # type_="size", # 映射类型，可选'color', 'size'
        
    # ),
    # 提示框配置项
    tooltip_opts=opts.TooltipOpts(
        is_show=True, # 是否显示
    ),
    # 坐标轴配置项
    xaxis_opts=opts.AxisOpts(
        
    ),
    
)
# 系列配置项
line1.set_series_opts(
    # 标签配置项
    label_opts=opts.LabelOpts(
        is_show=False, # 是否显示
    ),
    # 线条样式配置项
    linestyle_opts=opts.LineStyleOpts(
        width=1, # 线条宽度
    ),
)
line1.render(x[0] + ".html")
line1 .render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c16544b53ec244b0b11b1503fae00101" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c16544b53ec244b0b11b1503fae00101 = echarts.init(
#                     document.getElementById('c16544b53ec244b0b11b1503fae00101'), 'light', {renderer: 'canvas'});
#                 var option_c16544b53ec244b0b11b1503fae00101 = {
#     "backgroundColor": "transparent",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     57
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     31
#                 ],
#                 [
#                     "\u8001\u864e",
#                     109
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     86
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     72
#                 ],
#                 [
#                     "\u718a\u732b",
#                     104
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     62
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     68
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     21
#                 ],
#                 [
#                     "\u8001\u864e",
#                     55
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     90
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     110
#                 ],
#                 [
#                     "\u718a\u732b",
#                     70
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     114
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {},
#             "type": "scroll",
#             "show": true,
#             "right": "5px",
#             "orient": "horizontal",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "icon": "circle",
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e3b\u6807\u9898",
#             "link": "https://www.baidu.com",
#             "target": "blank",
#             "subtext": "\u526f\u6807\u9898",
#             "sublink": "https://www.baidu.com",
#             "subtarget": "blank",
#             "left": "5px",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "showDetail": true,
#         "showDataShadow": true,
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "horizontal",
#         "zoomLock": false,
#         "fi
